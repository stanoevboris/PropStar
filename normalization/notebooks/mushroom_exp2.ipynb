# %%
import sys
# sys.path is a list of absolute path strings
sys.path.append('/mnt/sda/boris_stanoev/PropStar/')

# %%
from normalization.normalize import Normalize
from sklearn.datasets import fetch_openml

# %%
data = fetch_openml(name='mushroom')
denormalized_table = data.data.join(data.target)
# Out:
# /mnt/sda/boris_stanoev/PropStar/venv/lib/python3.10/site-packages/sklearn/datasets/_openml.py:303: UserWarning: Multiple active versions of the dataset matching the name mushroom exist. Versions may be fundamentally different, returning version 1.
#   warn(
# /mnt/sda/boris_stanoev/PropStar/venv/lib/python3.10/site-packages/sklearn/datasets/_openml.py:1002: FutureWarning: The default value of `parser` will change from `'liac-arff'` to `'auto'` in 1.4. You can set `parser='auto'` to silence this warning. Therefore, an `ImportError` will be raised from 1.4 if the dataset is dense and pandas is not installed. Note that the pandas parser may return different data types. See the Notes Section in fetch_openml's API doc for details.
#   warn(

# %%
denormalized_table.rename(columns={'bruises%3F':'bruises'}, inplace=True)

# %%
denormalized_table.columns.values
# Out:
# array(['cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat', 'class'],
#       dtype=object)

# %%
cap_columns = ['cap-shape', 'cap-surface', 'cap-color']
gill_columns = ['gill-attachment', 'gill-spacing', 'gill-size', 'gill-color']
stalk_columns = ['stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
       'stalk-surface-below-ring', 'stalk-color-above-ring',
       'stalk-color-below-ring']
veil_columns = ['veil-type', 'veil-color']
ring_columns = ['ring-number', 'ring-type']
spore_print_color_columns = ['spore-print-color']
mushroom_columns = ['bruises', 'odor', 'population', 'habitat', 'class']
all_columns = denormalized_table.columns.values

# %%
print(denormalized_table[[*cap_columns]].count())
print(denormalized_table[[*cap_columns]].drop_duplicates().count())
# Out:
# cap-shape      8124
# cap-surface    8124
# cap-color      8124
# dtype: int64
# cap-shape      90
# cap-surface    90
# cap-color      90
# dtype: int64

# %%
print(denormalized_table[[*gill_columns]].count())
print(denormalized_table[[*gill_columns]].drop_duplicates().count())
# Out:
# gill-attachment    8124
# gill-spacing       8124
# gill-size          8124
# gill-color         8124
# dtype: int64
# gill-attachment    34
# gill-spacing       34
# gill-size          34
# gill-color         34
# dtype: int64

# %%
print(denormalized_table[[*stalk_columns]].count())
print(denormalized_table[[*stalk_columns]].drop_duplicates().count())
# Out:
# stalk-shape                 8124
# stalk-root                  5644
# stalk-surface-above-ring    8124
# stalk-surface-below-ring    8124
# stalk-color-above-ring      8124
# stalk-color-below-ring      8124
# dtype: int64
# stalk-shape                 63
# stalk-root                  36
# stalk-surface-above-ring    63
# stalk-surface-below-ring    63
# stalk-color-above-ring      63
# stalk-color-below-ring      63
# dtype: int64

# %%
print(denormalized_table[[*veil_columns]].count())
print(denormalized_table[[*veil_columns]].drop_duplicates().count())
# Out:
# veil-type     8124
# veil-color    8124
# dtype: int64
# veil-type     4
# veil-color    4
# dtype: int64

# %%
print(denormalized_table[[*ring_columns]].count())
print(denormalized_table[[*ring_columns]].drop_duplicates().count())
# Out:
# ring-number    8124
# ring-type      8124
# dtype: int64
# ring-number    7
# ring-type      7
# dtype: int64

# %%
denormalized_table[[*stalk_columns]]
# Out:
#      stalk-shape stalk-root stalk-surface-above-ring stalk-surface-below-ring  \
# 0              e          e                        s                        s
# 1              e          c                        s                        s
# 2              e          c                        s                        s
# 3              e          e                        s                        s
# 4              t          e                        s                        s
# ...          ...        ...                      ...                      ...
# 8119           e        NaN                        s                        s
# 8120           e        NaN                        s                        s
# 8121           e        NaN                        s                        s
# 8122           t        NaN                        s                        k
# 8123           e        NaN                        s                        s
#
# ...

# %%
norm = Normalize(denormalized_table=denormalized_table, denormalized_table_name="original_table")

# %%
norm.create_entity(source_entity_name="original_table", target_entity_name="mushroom", columns=all_columns,
                   distinct_values=True, retain_columns=['mushroom_id'])

norm.create_entity(source_entity_name="mushroom", target_entity_name="population_type", columns=['population'],
                   distinct_values=True)
norm.create_entity(source_entity_name="mushroom", target_entity_name="habitat_type", columns=['habitat'],
                   distinct_values=True)
norm.create_entity(source_entity_name="mushroom", target_entity_name="bruises_type", columns=['bruises'],
                   distinct_values=True)

norm.create_entity(source_entity_name="mushroom", target_entity_name="odor_type", columns=['odor'],
                   distinct_values=True)

# %%
norm.create_entity(source_entity_name="mushroom", target_entity_name="spore_print_color_type", columns=spore_print_color_columns,
                   distinct_values=True)

# %%
norm.create_entity(source_entity_name="mushroom", target_entity_name="cap", columns=cap_columns,
                   distinct_values=True, retain_columns=['mushroom_id'])
norm.create_entity(source_entity_name="cap", target_entity_name="cap_shape_type", columns=['cap-shape'],
                   distinct_values=True)

norm.create_entity(source_entity_name="cap", target_entity_name="cap_surface_type", columns=['cap-surface'],
                   distinct_values=True)
norm.create_entity(source_entity_name="cap", target_entity_name="cap_color_type", columns=['cap-color'],
                   distinct_values=True)

# %%
norm.create_entity(source_entity_name="mushroom", target_entity_name="gill", columns=gill_columns,
                   distinct_values=True, retain_columns=['mushroom_id'])

norm.create_entity(source_entity_name="gill", target_entity_name="gill_attachment_type", columns=['gill-attachment'],
                   distinct_values=True)

# %%
norm.create_entity(source_entity_name="mushroom", target_entity_name="stalk", columns=stalk_columns,
                   distinct_values=True, retain_columns=['mushroom_id'])

norm.create_entity(source_entity_name="stalk", target_entity_name="stalk_shape_type", columns=['stalk-shape'],
                   distinct_values=True)

norm.create_entity(source_entity_name="stalk", target_entity_name="stalk_root_type", columns=['stalk-root'],
                   distinct_values=True)

norm.create_entity(source_entity_name="stalk", target_entity_name="stalk_color_above_ring_type", columns=['stalk-color-above-ring'],
                   distinct_values=True)

norm.create_entity(source_entity_name="stalk", target_entity_name="stalk_color_below_ring_type", columns=['stalk-color-below-ring'],
                   distinct_values=True)

# %%
norm.create_entity(source_entity_name="mushroom", target_entity_name="veil", columns=veil_columns,
                   distinct_values=True, retain_columns=['mushroom_id'])

norm.create_entity(source_entity_name="veil", target_entity_name="veil_type", columns=['veil-type'],
                   distinct_values=True)

norm.create_entity(source_entity_name="veil", target_entity_name="veil_color_type", columns=['veil-color'],
                   distinct_values=True)

# %%
norm.create_entity(source_entity_name="mushroom", target_entity_name="ring", columns=ring_columns,
                   distinct_values=True, retain_columns=['mushroom_id'])

norm.create_entity(source_entity_name="ring", target_entity_name="ring_number_type", columns=['ring-number'],
                   distinct_values=True)

norm.create_entity(source_entity_name="ring", target_entity_name="ring_type", columns=['ring-type'],
                   distinct_values=True)

# %%
norm.remove_entity("original_table")

# %%
print(norm.primary_keys)
print("\n")
print(norm.relations)
print("\n")
print(norm.entity_set.keys())
# Out:
# {'mushroom': 'mushroom_id', 'population_type': 'population_type_id', 'habitat_type': 'habitat_type_id', 'bruises_type': 'bruises_type_id', 'odor_type': 'odor_type_id', 'spore_print_color_type': 'spore_print_color_type_id', 'cap': 'cap_id', 'cap_shape_type': 'cap_shape_type_id', 'cap_surface_type': 'cap_surface_type_id', 'cap_color_type': 'cap_color_type_id', 'gill': 'gill_id', 'gill_attachment_type': 'gill_attachment_type_id', 'stalk': 'stalk_id', 'stalk_shape_type': 'stalk_shape_type_id', 'stalk_root_type': 'stalk_root_type_id', 'stalk_color_above_ring_type': 'stalk_color_above_ring_type_id', 'stalk_color_below_ring_type': 'stalk_color_below_ring_type_id', 'veil': 'veil_id', 'veil_type': 'veil_type_id', 'veil_color_type': 'veil_color_type_id', 'ring': 'ring_id', 'ring_number_type': 'ring_number_type_id', 'ring_type': 'ring_type_id'}
#
#
# ...

# %%
for entity in norm.entity_set.keys():
    print(
        f"ALTER TABLE {entity} ADD CONSTRAINT PK_{entity} PRIMARY KEY ({norm.primary_keys[entity]});")

for parent_table in norm.relations:
    for child_table in norm.relations[parent_table]:
        print(f"ALTER TABLE {child_table} ADD CONSTRAINT FK_{child_table}_{parent_table} "
              f"FOREIGN KEY ({norm.relations[parent_table][child_table][1]}) "
              f"REFERENCES {parent_table}({norm.relations[parent_table][child_table][0]}));")
# Out:
# ALTER TABLE mushroom ADD CONSTRAINT PK_mushroom PRIMARY KEY (mushroom_id);
# ALTER TABLE population_type ADD CONSTRAINT PK_population_type PRIMARY KEY (population_type_id);
# ALTER TABLE habitat_type ADD CONSTRAINT PK_habitat_type PRIMARY KEY (habitat_type_id);
# ALTER TABLE bruises_type ADD CONSTRAINT PK_bruises_type PRIMARY KEY (bruises_type_id);
# ALTER TABLE odor_type ADD CONSTRAINT PK_odor_type PRIMARY KEY (odor_type_id);
# ALTER TABLE spore_print_color_type ADD CONSTRAINT PK_spore_print_color_type PRIMARY KEY (spore_print_color_type_id);
# ALTER TABLE cap ADD CONSTRAINT PK_cap PRIMARY KEY (cap_id);
# ALTER TABLE cap_shape_type ADD CONSTRAINT PK_cap_shape_type PRIMARY KEY (cap_shape_type_id);
# ALTER TABLE cap_surface_type ADD CONSTRAINT PK_cap_surface_type PRIMARY KEY (cap_surface_type_id);
# ALTER TABLE cap_color_type ADD CONSTRAINT PK_cap_color_type PRIMARY KEY (cap_color_type_id);
# ALTER TABLE gill ADD CONSTRAINT PK_gill PRIMARY KEY (gill_id);
# ...

# %%
norm.persist_entity_set(database_name="mushroom_exp2")
# Out:
# 2023-09-17 20:25:45,713 INFO sqlalchemy.engine.Engine SELECT CAST(SERVERPROPERTY('ProductVersion') AS VARCHAR)
# 2023-09-17 20:25:45,714 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-09-17 20:25:45,717 INFO sqlalchemy.engine.Engine SELECT schema_name()
# 2023-09-17 20:25:45,718 INFO sqlalchemy.engine.Engine [generated in 0.00119s] ()
# 2023-09-17 20:25:45,722 INFO sqlalchemy.engine.Engine SELECT CAST('test max support' AS NVARCHAR(max))
# 2023-09-17 20:25:45,723 INFO sqlalchemy.engine.Engine [generated in 0.00101s] ()
# 2023-09-17 20:25:45,725 INFO sqlalchemy.engine.Engine SELECT 1 FROM fn_listextendedproperty(default, default, default, default, default, default, default)
# 2023-09-17 20:25:45,726 INFO sqlalchemy.engine.Engine [generated in 0.00105s] ()
# 2023-09-17 20:25:45,729 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-09-17 20:25:45,730 INFO sqlalchemy.engine.Engine IF (SCHEMA_ID('mushroom_exp2') IS NOT NULL) BEGIN DROP SCHEMA [mushroom_exp2]; END
# ...
